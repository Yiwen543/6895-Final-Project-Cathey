# %% [markdown]
# # Cathey — LoRA Fine-Tuning Notebook (Google Colab + H100)
#
# **Platform:** Google Colab with H100 GPU
# **Base model:** `Qwen/Qwen2.5-3B-Instruct`
# **Adapter output:** `cathey_lora_adapter/final_adapter/` inside your Google Drive project folder
#
# ### Sections
# 1. Install dependencies
# 2. Mount Google Drive & set working directory
# 3. Import libraries & configuration
# 4. Generate training data
# 5. Load tokenizer & dataset
# 6. Format examples with chat template
# 7. Load model & configure LoRA
# 8. Train
# 9. Save adapter
# 10. Inference test

# %%
# Install all required packages into the current Colab kernel
import sys
# !{sys.executable} -m pip install -q -U transformers datasets trl peft accelerate torchao
print("All packages installed.")
# Out:
# All packages installed.

# %%
from google.colab import drive
import os

# Mount Google Drive (you will be prompted to authenticate on first run)
drive.mount('/content/drive')

# Set working directory to your project folder in Drive
project_path = '/content/drive/MyDrive/6895-Final-Project-Cathey'

if os.path.exists(project_path):
    os.chdir(project_path)
    print(f'Working directory set to: {os.getcwd()}')
    if os.path.exists('finetune'):
        print('finetune/ folder found:')
        import subprocess
        subprocess.run(['ls', 'finetune'])
    else:
        print('WARNING: finetune/ folder not found in project directory.')
else:
    print(f'ERROR: Project path not found: {project_path}')
    print('Contents of Drive root:')
    import subprocess
    subprocess.run(['ls', '/content/drive/MyDrive/'])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Working directory set to: /content/drive/MyDrive/6895-Final-Project-Cathey
# finetune/ folder found:

# %%
import sys
print('Kernel Python:', sys.executable)
print('Python version:', sys.version)
# Out:
# Kernel Python: /usr/bin/python3
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# Section 2: Imports
import os
import json
import torch

from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import LoraConfig, get_peft_model
from trl import SFTTrainer, SFTConfig

# %%
# Section 3: Configuration — aligns with config.py constants
MODEL_NAME = "Qwen/Qwen2.5-3B-Instruct"

TRAIN_FILE        = "train.jsonl"
VAL_FILE          = "val.jsonl"
OUTPUT_DIR        = "./cathey_lora_adapter"          # matches config.py LORA_ADAPTER_DIR
FINAL_ADAPTER_DIR = OUTPUT_DIR + "/final_adapter"   # matches config.py LORA_INFERENCE_PATH
CHECKPOINT_DIR    = OUTPUT_DIR + "/checkpoints"

DEVICE = "cuda" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu")

# Create output directories
os.makedirs(OUTPUT_DIR,        exist_ok=True)
os.makedirs(CHECKPOINT_DIR,    exist_ok=True)
os.makedirs(FINAL_ADAPTER_DIR, exist_ok=True)

print("MODEL_NAME       =", MODEL_NAME)
print("TRAIN_FILE       =", TRAIN_FILE)
print("VAL_FILE         =", VAL_FILE)
print("OUTPUT_DIR       =", OUTPUT_DIR)
print("FINAL_ADAPTER_DIR=", FINAL_ADAPTER_DIR)
print("DEVICE           =", DEVICE)
# Out:
# MODEL_NAME       = Qwen/Qwen2.5-3B-Instruct
# TRAIN_FILE       = train.jsonl
# VAL_FILE         = val.jsonl
# OUTPUT_DIR       = ./cathey_lora_adapter
# FINAL_ADAPTER_DIR= ./cathey_lora_adapter/final_adapter
# DEVICE           = cuda

# %%
# Section 3.5: Generate train.jsonl / val.jsonl from finetune/train_data.py
# Forces regeneration even if files already exist (ensures data is up-to-date)
import sys, json, os, random as _rng

if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# Remove stale files before regenerating
for f in [TRAIN_FILE, VAL_FILE]:
    if os.path.exists(f):
        os.remove(f)
print("Existing data files removed. Regenerating...")

try:
    from finetune.train_data import RAW_TRAIN_DATA

    data = [{"input": inp, "output": out} for inp, out in RAW_TRAIN_DATA]
    _rng.seed(42)
    _rng.shuffle(data)

    n_val   = max(200, int(len(data) * 0.1))
    val_d   = data[:n_val]
    train_d = data[n_val:]

    with open(TRAIN_FILE, 'w', encoding='utf-8') as fh:
        for item in train_d:
            fh.write(json.dumps(item, ensure_ascii=False) + '\n')
    with open(VAL_FILE, 'w', encoding='utf-8') as fh:
        for item in val_d:
            fh.write(json.dumps(item, ensure_ascii=False) + '\n')

    print(f"Generated: {TRAIN_FILE} — {len(train_d)} train examples")
    print(f"Generated: {VAL_FILE}   — {len(val_d)} validation examples")
except ImportError as e:
    print(f"ImportError: {e}. Check that finetune/train_data.py exists.")
# Out:
# Existing data files removed. Regenerating...
# Generated: train.jsonl — 20250 train examples
# Generated: val.jsonl   — 2250 validation examples

# %%
# Section 4: Verify training and validation files exist
assert os.path.exists(TRAIN_FILE), f"Training file not found: {TRAIN_FILE}"
assert os.path.exists(VAL_FILE),   f"Validation file not found: {VAL_FILE}"
print("Training and validation files found.")
# Out:
# Training and validation files found.

# %%
# Section 5: Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Tokenizer loaded.")
print("Pad token:", tokenizer.pad_token)
# Out:
# Tokenizer loaded.
# Pad token: <|endoftext|>

# %%
# Section 6: Load dataset from JSONL files
dataset = load_dataset(
    "json",
    data_files={
        "train":      TRAIN_FILE,
        "validation": VAL_FILE,
    }
)

print(dataset)
print("Train size:     ", len(dataset["train"]))
print("Validation size:", len(dataset["validation"]))
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output'],
#         num_rows: 20250
#     })
#     validation: Dataset({
#         features: ['input', 'output'],
#         num_rows: 2250
#     })
# })
# Train size:      20250
# Validation size: 2250

# %%
import json

EXTRA_TRAIN_EXAMPLES = [
    # general_qa — greetings and conversational filler (NOT invalid)
    {"input": "Cathey, hello!",       "output": '{"type":"general_qa","answer":"Hello! How can I help you?"}'},
    {"input": "Cathey, never mind.",  "output": '{"type":"general_qa","answer":"No problem, just let me know if you need anything."}'},
    {"input": "Cathey, okay thanks.", "output": '{"type":"general_qa","answer":"You\'re welcome!"}'},
    # general_qa — knowledge questions
    {"input": "Cathey, how do I eat an apple?",          "output": '{"type":"general_qa","answer":"Wash it first, then eat it."}'},
    {"input": "Cathey, what time is it?",                "output": '{"type":"general_qa","answer":"I don\'t have access to a clock, but you can check your phone."}'},
    {"input": "Cathey, can I eat leftovers after 3 days?","output": '{"type":"general_qa","answer":"Yes, most cooked food is safe for 3-4 days in the fridge."}'},
    {"input": "Cathey, what's the weather like?",        "output": '{"type":"general_qa","answer":"I don\'t have weather data, but you can check a weather app."}'},
    {"input": "Cathey, how do I boil an egg?",           "output": '{"type":"general_qa","answer":"Place the egg in boiling water for 6-12 minutes depending on your preference."}'},
    {"input": "Cathey, what is 2 plus 2?",               "output": '{"type":"general_qa","answer":"4."}'},
    # needs_clarification — vague temperature requests
    {"input": "Cathey, lower the temperature.", "output": '{"type":"needs_clarification","question":"What temperature would you like me to set the AC to?","options":["lower_ac_temperature","raise_ac_temperature"]}'},
    {"input": "Cathey, make it warmer.",        "output": '{"type":"needs_clarification","question":"Would you like me to raise the AC temperature or close the window?","options":["raise_ac_temperature","close_window"]}'},
    # invalid — truly unintelligible only
    {"input": "Hmm.",         "output": '{"type":"invalid"}'},
    {"input": "Just testing.","output": '{"type":"invalid"}'},
]

EXTRA_VAL_EXAMPLES = [
    {"input": "Cathey, how long should I microwave rice?", "output": '{"type":"general_qa","answer":"About 2-3 minutes, stirring halfway through."}'},
    {"input": "Cathey, hello there!",                     "output": '{"type":"general_qa","answer":"Hello! How can I help?"}'},
    {"input": "Cathey, raise the temperature a little.",  "output": '{"type":"needs_clarification","question":"What temperature would you like me to set the AC to?","options":["lower_ac_temperature","raise_ac_temperature"]}'},
    {"input": "Hmm hmm.", "output": '{"type":"invalid"}'},
]

with open(TRAIN_FILE, "a", encoding="utf-8") as f:
    for ex in EXTRA_TRAIN_EXAMPLES:
        f.write(json.dumps(ex, ensure_ascii=False) + "\n")

with open(VAL_FILE, "a", encoding="utf-8") as f:
    for ex in EXTRA_VAL_EXAMPLES:
        f.write(json.dumps(ex, ensure_ascii=False) + "\n")

print(f"Appended {len(EXTRA_TRAIN_EXAMPLES)} corrective train examples")
print(f"Appended {len(EXTRA_VAL_EXAMPLES)} corrective validation examples")
# Out:
# Appended 13 corrective train examples
# Appended 4 corrective validation examples

# %%
# Section 7: Preview a raw training sample
print("Sample train row:")
print(dataset["train"][0])
# Out:
# Sample train row:
# {'input': 'Hey Cathey, the room is over-illuminated.', 'output': '{"type": "needs_clarification", "question": "Would you like me to dim the light or close the curtain?", "options": ["dim_light", "close_curtain"]}'}

# %%
# System prompt used for both training and inference
# Must match UNIFIED_SYSTEM_PROMPT in llm_parser.py exactly
SYSTEM_PROMPT = """
Return exactly one JSON object.

Allowed outputs:

{"type":"direct_command","device":"light|curtain|window|ac","action":"turn_on|turn_off|set_brightness|rgb_cycle|open|close|set_position|set_temperature","value":null_or_int}

{"type":"needs_clarification","question":"...","options":["...","..."]}

{"type":"general_qa","answer":"..."}

{"type":"invalid"}

Rules:
- If the user directly names a device and a clear action, always output direct_command.
- If the user makes an indirect or ambiguous home-control request, output needs_clarification.
- If the user asks a normal non-device question, output general_qa.
- If there is no meaningful request, output invalid.
- For the same kind of ambiguous request, keep the question and options consistent.
- Output JSON only.
- No extra text.
""".strip()

# %%
# Section 9: Format training examples using the model's chat template
# tokenizer.apply_chat_template() handles Qwen2.5's <|im_start|>/<|im_end|> format
# and remains compatible with any future model swap.

def format_example(example):
    messages = [
        {"role": "system",    "content": SYSTEM_PROMPT},
        {"role": "user",      "content": example["input"]},
        {"role": "assistant", "content": example["output"]},
    ]
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=False,  # False: assistant turn is included in training target
    )
    return {"text": text}

dataset = dataset.map(format_example)
print("Formatting done. Sample (first 300 chars):")
print(dataset["train"][0]["text"][:300], "...")
# Out:
# Map:   0%|          | 0/20250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2250 [00:00<?, ? examples/s]
# Formatting done. Sample (first 300 chars):
# <|im_start|>system
# Return exactly one JSON object.
#
# Allowed outputs:
#
# {"type":"direct_command","device":"light|curtain|window|ac","action":"turn_on|turn_off|set_brightness|rgb_cycle|open|close|set_position|set_temperature","value":null_or_int}
#
# {"type":"needs_clarification","question":"...","options ...

# %%
# Section 10: Preview the full formatted training sample
print("Full formatted sample:")
print(dataset["train"][0]["text"])
# Out:
# Full formatted sample:
# <|im_start|>system
# Return exactly one JSON object.
#
# Allowed outputs:
#
# {"type":"direct_command","device":"light|curtain|window|ac","action":"turn_on|turn_off|set_brightness|rgb_cycle|open|close|set_position|set_temperature","value":null_or_int}
#
# {"type":"needs_clarification","question":"...","options":["...","..."]}
#
# {"type":"general_qa","answer":"..."}
#
# {"type":"invalid"}
#
# Rules:
# - If the user directly names a device and a clear action, always output direct_command.
# - If the user makes an indirect or ambiguous home-control request, output needs_clarification.
# - If the user asks a normal non-device question, output general_qa.
# - If there is no meaningful request, output invalid.
# - For the same kind of ambiguous request, keep the question and options consistent.
# - Output JSON only.
# - No extra text.<|im_end|>
# <|im_start|>user
# Hey Cathey, the room is over-illuminated.<|im_end|>
# <|im_start|>assistant
# {"type": "needs_clarification", "question": "Would you like me to dim the light or close the curtain?", "options": ["dim_light", "close_curtain"]}<|im_end|>

# %%
# Section 11: Load base model
# CUDA (H100): float16, device_map=auto  |  MPS: float16, explicit placement  |  CPU: float32
if torch.cuda.is_available():
    dtype = torch.float16
    dmap  = "auto"
elif torch.backends.mps.is_available():
    dtype = torch.float16
    dmap  = {"": "mps"}
else:
    dtype = torch.float32
    dmap  = "cpu"

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=dtype,
    device_map=dmap,
)
print(f"Base model loaded on {next(model.parameters()).device} [{dtype}]")
# Out:
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Base model loaded on cuda:0 [torch.float16]

# %%
# Section 12: Configure LoRA adapter
# r=8, alpha=16 → ~0.06% trainable parameters (1.8M / 3.1B)
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# trainable params: 1,843,200 || all params: 3,087,781,888 || trainable%: 0.0597

# %%
# Section 13: Training configuration
# Checkpoints saved every epoch to CHECKPOINT_DIR (max 2 kept)
# Final adapter saved separately in Section 15b via trainer.model.save_pretrained()
training_args = SFTConfig(
    output_dir=CHECKPOINT_DIR,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=8,          # effective batch size = 8
    num_train_epochs=5,
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,
    logging_steps=10,
    eval_strategy="epoch",
    save_strategy="epoch",                  # save checkpoint each epoch
    save_total_limit=2,                     # keep only the last 2 checkpoints
    fp16=torch.cuda.is_available(),
    bf16=False,
    report_to="none",
)
# Out:
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.

# %%
# Section 14: Build SFTTrainer
# SFTTrainer applies response-only loss masking by default,
# so the loss is computed only on the assistant turn.
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    processing_class=tokenizer,
)
print("Trainer ready.")
# Out:
# Adding EOS to train dataset:   0%|          | 0/20250 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/20250 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2250 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2250 [00:00<?, ? examples/s]
# Trainer ready.

# %%
# Section 15: Start training
# On H100: ~2-3 min/epoch for 20k examples  |  CPU/MPS: ~15-30 min/epoch
trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='12660' max='12660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12660/12660 2:54:58, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.046791</td>
#       <td>0.045461</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.040917</td>
#       <td>0.041301</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.039791</td>
#       <td>0.040184</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.039871</td>
#       <td>0.039424</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.038529</td>
#       <td>0.039187</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12660, training_loss=0.0912520943800985, metrics={'train_runtime': 10498.851, 'train_samples_per_second': 9.644, 'train_steps_per_second': 1.206, 'total_flos': 4.06831582949376e+17, 'train_loss': 0.0912520943800985})

# %%
# Section 15b: Save LoRA adapter and tokenizer
# Saves to FINAL_ADAPTER_DIR which matches config.py LORA_INFERENCE_PATH
# LLMParser loads this adapter automatically at runtime if the directory exists.
import os

os.makedirs(FINAL_ADAPTER_DIR, exist_ok=True)
trainer.model.save_pretrained(FINAL_ADAPTER_DIR)
tokenizer.save_pretrained(FINAL_ADAPTER_DIR)
print(f"Adapter saved to {FINAL_ADAPTER_DIR}")
print("config.py LORA_INFERENCE_PATH already points here — no extra step needed.")

expected = ["adapter_config.json", "adapter_model.safetensors"]
for fn in expected:
    path = os.path.join(FINAL_ADAPTER_DIR, fn)
    print(f"  {'OK' if os.path.exists(path) else 'MISSING'} {fn}")
# Out:
# Adapter saved to ./cathey_lora_adapter/final_adapter
# config.py LORA_INFERENCE_PATH already points here — no extra step needed.
#   OK adapter_config.json
#   OK adapter_model.safetensors

# %%
# Section 16: Inference helpers
# JSON stop criterion: halt generation as soon as a complete JSON object is produced
from transformers import StoppingCriteria, StoppingCriteriaList

def _extract_first_json(text: str):
    start = text.find("{")
    if start == -1:
        return None
    depth = 0
    for i in range(start, len(text)):
        if text[i] == "{":
            depth += 1
        elif text[i] == "}":
            depth -= 1
            if depth == 0:
                return text[start:i + 1]
    return None

def _has_complete_json(text: str) -> bool:
    start = text.find("{")
    if start == -1:
        return False
    depth = 0
    for ch in text[start:]:
        if ch == "{":   depth += 1
        elif ch == "}": depth -= 1
        if depth == 0:  return True
    return False

class JsonStopOnComplete(StoppingCriteria):
    def __init__(self, tokenizer, prompt_length: int):
        self.tokenizer     = tokenizer
        self.prompt_length = prompt_length

    def __call__(self, input_ids, scores, **kwargs):
        generated_ids = input_ids[0][self.prompt_length:]
        text = self.tokenizer.decode(generated_ids, skip_special_tokens=True)
        return _has_complete_json(text)


def run_inference(test_input: str, max_new_tokens: int = 80):
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": test_input},
    ]
    prompt = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    prompt_length = inputs["input_ids"].shape[1]

    stopping_criteria = StoppingCriteriaList([
        JsonStopOnComplete(tokenizer, prompt_length)
    ])

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            stopping_criteria=stopping_criteria,
            use_cache=True,
        )

    generated_ids = outputs[0][prompt_length:]
    raw_output = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
    json_str   = _extract_first_json(raw_output)
    return {"raw_output": raw_output, "first_json": json_str}

# %%
# Section 18: Inference test — run after training to verify the fine-tuned adapter
test_inputs = [
    "Cathey, turn on the light.",
    "Cathey, turn off the light.",
    "Cathey, open the curtain.",
    "Cathey, close the window.",
    "Cathey, set the AC to 24 degrees.",
    "Cathey, I feel a little bit cold.",
    "Cathey, I feel cold.",
    "Cathey, it's a bit dark.",
    "Cathey, this room feels dark.",
    "Cathey, how do I make tea?",
    "Cathey, hello!",
    "Turn on the light.",          # no wake word → should be invalid
]

for x in test_inputs:
    print("=" * 70)
    print("INPUT :", x)
    print("OUTPUT:", run_inference(x))
# Out:
# ======================================================================
# INPUT : Cathey, turn on the light.
# OUTPUT: {'raw_output': '{"type": "direct_command", "device": "light", "action": "turn_on", "value": null, "reply": "Turning on the light."}', 'first_json': '{"type": "direct_command", "device": "light", "action": "turn_on", "value": null, "reply": "Turning on the light."}'}
# ======================================================================
# INPUT : Cathey, turn off the light.
# OUTPUT: {'raw_output': '{"type": "direct_command", "device": "light", "action": "turn_off", "value": null, "reply": "Turning off the light."}', 'first_json': '{"type": "direct_command", "device": "light", "action": "turn_off", "value": null, "reply": "Turning off the light."}'}
# ======================================================================
# INPUT : Cathey, open the curtain.
# OUTPUT: {'raw_output': '{"type": "direct_command", "device": "curtain", "action": "open", "value": null, "reply": "Curtain opened."}', 'first_json': '{"type": "direct_command", "device": "curtain", "action": "open", "value": null, "reply": "Curtain opened."}'}
# ======================================================================
# INPUT : Cathey, close the window.
# OUTPUT: {'raw_output': '{"type": "direct_command", "device": "window", "action": "close", "value": null, "reply": "Window closed."}', 'first_json': '{"type": "direct_command", "device": "window", "action": "close", "value": null, "reply": "Window closed."}'}
# ======================================================================
# INPUT : Cathey, set the AC to 24 degrees.
# OUTPUT: {'raw_output': '{"type": "direct_command", "device": "ac", "action": "set_temperature", "value": 24, "reply": "Setting AC to 24 degrees."}', 'first_json': '{"type": "direct_command", "device": "ac", "action": "set_temperature", "value": 24, "reply": "Setting AC to 24 degrees."}'}
# ======================================================================
# INPUT : Cathey, I feel a little bit cold.
# OUTPUT: {'raw_output': '{"type": "needs_clarification", "question": "Would you like me to close the window or raise the AC temperature?", "options": ["close_window", "raise_ac_temperature"]}', 'first_json': '{"type": "needs_clarification", "question": "Would you like me to close the window or raise the AC temperature?", "options": ["close_window", "raise_ac_temperature"]}'}
# ======================================================================
# INPUT : Cathey, I feel cold.
# OUTPUT: {'raw_output': '{"type": "needs_clarification", "question": "Would you like me to close the window or raise the AC temperature?", "options": ["close_window", "raise_ac_temperature"]}', 'first_json': '{"type": "needs_clarification", "question": "Would you like me to close the window or raise the AC temperature?", "options": ["close_window", "raise_ac_temperature"]}'}
# ======================================================================
# INPUT : Cathey, it's a bit dark.
# OUTPUT: {'raw_output': '{"type": "needs_clarification", "question": "Would you like me to turn on the light or open the curtain?", "options": ["turn_on_light", "open_curtain"]}', 'first_json': '{"type": "needs_clarification", "question": "Would you like me to turn on the light or open the curtain?", "options": ["turn_on_light", "open_curtain"]}'}
# ======================================================================
# INPUT : Cathey, this room feels dark.
# OUTPUT: {'raw_output': '{"type": "needs_clarification", "question": "Would you like me to turn on the light or open the curtain?", "options": ["turn_on_light", "open_curtain"]}', 'first_json': '{"type": "needs_clarification", "question": "Would you like me to turn on the light or open the curtain?", "options": ["turn_on_light", "open_curtain"]}'}
# ======================================================================
# INPUT : Cathey, how do I make tea?
# OUTPUT: {'raw_output': '{"type": "general_qa", "answer": "Boil water, pour over a tea bag or leaves, and steep for a few minutes."}', 'first_json': '{"type": "general_qa", "answer": "Boil water, pour over a tea bag or leaves, and steep for a few minutes."}'}
# ======================================================================
# INPUT : Cathey, hello!
# OUTPUT: {'raw_output': '{"type": "needs_clarification", "question": "Would you like me to do something specific, like adjust lighting or temperature?", "options": ["adjust_lighting", "adjust_temperature"]}', 'first_json': '{"type": "needs_clarification", "question": "Would you like me to do something specific, like adjust lighting or temperature?", "options": ["adjust_lighting", "adjust_temperature"]}'}
# ======================================================================
# INPUT : Turn on the light.
# OUTPUT: {'raw_output': '{"type":"invalid"}', 'first_json': '{"type":"invalid"}'}

# %%
# Reference: how to reload the fine-tuned adapter in a fresh Colab session
# (run this cell instead of loading the base model from scratch)
#
# from transformers import AutoTokenizer, AutoModelForCausalLM
# from peft import PeftModel
# import torch
#
# MODEL_NAME   = "Qwen/Qwen2.5-3B-Instruct"
# ADAPTER_PATH = "./cathey_lora_adapter/final_adapter"  # matches config.py LORA_INFERENCE_PATH
#
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# if tokenizer.pad_token is None:
#     tokenizer.pad_token = tokenizer.eos_token
#
# base_model = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME,
#     torch_dtype=torch.float16,
#     device_map="auto",
# )
# model = PeftModel.from_pretrained(base_model, ADAPTER_PATH)
# model.eval()
# print("Fine-tuned adapter loaded.")
